# %% [markdown]
# ### Evaluate transfers seems to still be choosing players already in the team:

# %%
import os
os.chdir(os.path.dirname(os.getcwd()))
from season_simulator import SeasonSimulator
from strategies.sample import Strategy
strategy = Strategy()
sim = SeasonSimulator(2018, strategy)
sim.simulate()
# Out:
# Build team with 3 players chosen by raw score, 12 by roi. Total score = 77.50000000000001. Remaining budget = 35.0
# Evaluating team for gw 2 ... made 1 transfer(s).
# Evaluating team for gw 3 ... made 1 transfer(s).
# Evaluating team for gw 4 ... made 1 transfer(s).
# Evaluating team for gw 5 ... made 1 transfer(s).
# Evaluating team for gw 6 ... made 1 transfer(s).
# Evaluating team for gw 7 ... made 1 transfer(s).
# Evaluating team for gw 8 ... made 1 transfer(s).
# Evaluating team for gw 9 ... made 1 transfer(s).
# Evaluating team for gw 10 ... made 1 transfer(s).
# Evaluating team for gw 11 ... made 1 transfer(s).
# Evaluating team for gw 12 ... made 1 transfer(s).
# Evaluating team for gw 13 ... made 1 transfer(s).
# Evaluating team for gw 14 ... made 1 transfer(s).
# Evaluating team for gw 15 ... made 1 transfer(s).
# Evaluating team for gw 16 ... made 0 transfer(s).
# Evaluating team for gw 17 ... made 1 transfer(s).
# Evaluating team for gw 18 ... made 0 transfer(s).
# Evaluating team for gw 19 ... made 2 transfer(s).
# Evaluating team for gw 20 ... made 1 transfer(s).
# Evaluating team for gw 21 ... made 1 transfer(s).
# Evaluating team for gw 22 ... made 1 transfer(s).
# Evaluating team for gw 23 ... made 1 transfer(s).
# Evaluating team for gw 24 ... made 1 transfer(s).
# Evaluating team for gw 25 ... made 1 transfer(s).
# Evaluating team for gw 26 ... made 1 transfer(s).
# Evaluating team for gw 27 ... made 0 transfer(s).
# Evaluating team for gw 28 ... made 0 transfer(s).
# Evaluating team for gw 29 ... made 0 transfer(s).
# Evaluating team for gw 30 ... made 0 transfer(s).
# Evaluating team for gw 31 ... made 0 transfer(s).
# Evaluating team for gw 32 ... made 2 transfer(s).
# Evaluating team for gw 33 ... made 0 transfer(s).
# Evaluating team for gw 34 ...
# ---------------------------------------------------------------------------
# AlreadySelected                           Traceback (most recent call last)
# <ipython-input-1-71128d9690ab> in <module>
#       5 strategy = Strategy()
#       6 sim = SeasonSimulator(2018, strategy)
# ----> 7 sim.simulate()
#
# ~toby\fpl-predictor\fpl_predictor\season_simulator.py in simulate(self, verbose)
#      44                         self.new_team.team.remove_player(remove)
#      45                         add = row[1]["new"]
# ---> 46                         self.new_team.add_player(add)
#      47                         self.transfers = self.transfers.append({"GW": gw, "out": remove, "in": add}, ignore_index=True)
#      48                         n_transfers -= 1
#
# ~toby\fpl-predictor\fpl_predictor\teambuilder.py in add_player(self, uuid)
#     295         score = self.scores.loc[uuid]["total_points (raw)"]
#     296         roi_score = self.scores.loc[uuid]["total_points (roi)"]
# --> 297         self.team.add_player(uuid, value, score, roi_score)
#
# ~toby\fpl-predictor\fpl_predictor\team.py in add_player(self, uuid, value, score, roi_score)
#      65             raise NotEnoughMoney()
#      66         if uuid in self.selected_players:
# ---> 67             raise AlreadySelected()
#      68         self.team = self.team.append(new_player, ignore_index=True)
#      69
#
# AlreadySelected:

# %%
sim.new_team.team.team
# Out:
#                                     uuid                        name position  \
# 0   2383688d-5af2-4461-9d90-52d6b545d970               Callum Wilson      FWD
# 1   da591bdf-e84a-42fe-8b79-b44ce3b3f3c4      Richarlison de Andrade      MID
# 2   77e4cc6d-d8af-42ab-a642-90124c75e9ed               Marcos Alonso      DEF
# 3   33dc9245-cc11-4a51-b629-8b38edf4884d                  Sadio Mané      MID
# 4   e4f4c6b2-48a1-4a43-b8eb-c23a8bb1c6da                José Holebas      DEF
# 5   ed6a341c-3cd3-4277-8b41-a240d0a762f5                Matt Doherty      DEF
# 6   b6dfc136-b651-4669-bed5-87ea35256c4a   Ederson Santana de Moraes       GK
# 7   325b053d-5ae2-4bcf-996e-3fe4b9c361cc             Virgil van Dijk      DEF
# 8   6c5f4c00-0af1-4775-8aa8-6a9267175d31               Heung-Min Son      MID
# 9   8542e3a4-c501-4d61-99b9-0b543577793d              Neil Etheridge       GK
# 10  82f8a53f-9896-4989-b06e-bb2f11ceeab1                  Paul Pogba      MID
# 11  4f3cf8ad-fb94-43c6-b51f-97e9d44d236c  David Luiz Moreira Marinho      DEF
# 12  938a0590-e703-4bd8-b636-3395e3f8acc1           James Ward-Prowse      MID
# 14  537dea3d-a42b-4739-8bbb-5843b7794ed0                Raúl Jiménez      FWD
#
#     value      score  roi_score
# 0    60.0   8.000000   0.133333
# 1    68.0  11.500000   0.174242
# 2    67.0  11.666667   0.176768
# 3   100.0   9.750000   0.098485
# 4    49.0   6.800000   0.141667
# 5    48.0   6.125000   0.133152
# 6    58.0   5.700000   0.100000
# 7    63.0   6.500000   0.104839
# 8    88.0   8.900000   0.101136
# 9    46.0   5.600000   0.121739
# 10   87.0   7.000000   0.080460
# 11   59.0   6.000000   0.101695
# 12   51.0   6.777778        NaN
# 14   68.0   7.111111        NaN

# %%
sim.new_team.evaluate_transfers()
# Out:
#                                     old                                   new  \
# 0  938a0590-e703-4bd8-b636-3395e3f8acc1  e56f60bf-7321-4764-9bb2-704a37ee5fa4
# 1  537dea3d-a42b-4739-8bbb-5843b7794ed0  388495e2-64da-4412-b0bf-51faa47aae80
#
#    score_differential  roi_differential  value_differential
# 0            0.122222               NaN                60.0
# 1            0.777778               NaN                49.0
